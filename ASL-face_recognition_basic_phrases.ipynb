# %%
import cv2
import mediapipe as mp
import pandas as pd
import numpy as np
import os
import time
from datetime import datetime

# === Configuration ===
DATA_DIR = r"C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\ASLFacialExpressionsLanguages"
os.makedirs(DATA_DIR, exist_ok=True)

# Ask user for label name
label = input("Shame").strip().lower()
SAVE_PATH = os.path.join(DATA_DIR, f"{label}.csv")

# === Landmark indices (reduce redundancy) ===
SELECTED_FACE_IDXS = [
    33, 133, 362, 263,   # eyes
    1, 2, 4, 5, 45, 275, # nose bridge + cheeks
    61, 291, 0, 17, 57, 287  # mouth + chin
]

# === MediaPipe Setup ===
mp_hands = mp.solutions.hands
mp_face = mp.solutions.face_mesh
mp_draw = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.8,
    min_tracking_confidence=0.8
)
face_mesh = mp_face.FaceMesh(
    static_image_mode=False,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.8
)

# === Smoothing helpers ===
def smooth_landmarks(landmarks, prev_landmarks, alpha=0.5):
    """Apply exponential moving average to reduce jitter."""
    if prev_landmarks is None:
        return landmarks
    return alpha * np.array(landmarks) + (1 - alpha) * np.array(prev_landmarks)

# === Dataset parameters ===
MAX_SAMPLES = 600       # capture limit per label
MIN_HAND_CONF = 0.75
FRAME_SKIP = 2          # process every 2nd frame to reduce duplicates
SMOOTHING = True

# === Camera setup ===
cap = cv2.VideoCapture(0)
frame_count = 0
saved_count = 0
data = []
prev_landmarks = None

print(f"📷 Starting data capture for '{label}' in 3 seconds...")
time.sleep(3)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    frame_count += 1

    # Skip frames to reduce redundancy
    if frame_count % FRAME_SKIP != 0:
        continue

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    hand_results = hands.process(rgb)
    face_results = face_mesh.process(rgb)

    row = []
    hands_detected = False
    face_detected = False

    # === HAND LANDMARKS (80%) ===
    hand_points = []
    if hand_results.multi_hand_landmarks:
        hands_detected = True
        for hand_landmarks in hand_results.multi_hand_landmarks[:2]:
            for lm in hand_landmarks.landmark:
                hand_points.extend([lm.x, lm.y, lm.z])
        if len(hand_results.multi_hand_landmarks) == 1:
            hand_points.extend([0] * (21 * 3))
    else:
        hand_points.extend([0] * (21 * 3 * 2))

    # === FACE LANDMARKS (20%) ===
    face_points = []
    if face_results.multi_face_landmarks:
        face_detected = True
        face_landmarks = face_results.multi_face_landmarks[0]
        for idx in SELECTED_FACE_IDXS:
            lm = face_landmarks.landmark[idx]
            face_points.extend([lm.x, lm.y, lm.z])
    else:
        face_points.extend([0] * (len(SELECTED_FACE_IDXS) * 3))

    # === Combine all features ===
    full_landmarks = hand_points + face_points

    # Smooth landmarks to reduce noise
    if SMOOTHING:
        full_landmarks = smooth_landmarks(full_landmarks, prev_landmarks)
    prev_landmarks = full_landmarks

    # === Append metadata ===
    row.extend(full_landmarks)
    row.append(label)
    row.append(datetime.utcnow().isoformat())

    # Save only if valid hand detected
    if hands_detected or face_detected:
        data.append(row)
        saved_count += 1
        status = f"✔ Collected ({saved_count}/{MAX_SAMPLES})"
    else:
        status = "❌ No hands or face detected"

    # Stop once enough samples are collected
    if saved_count >= MAX_SAMPLES:
        print("\n✅ Capture complete.")
        break

    # === Draw Landmarks ===
    if hand_results.multi_hand_landmarks:
        for hand_landmarks in hand_results.multi_hand_landmarks:
            mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    if face_results.multi_face_landmarks:
        for face_landmarks in face_results.multi_face_landmarks:
            mp_draw.draw_landmarks(
                frame, face_landmarks, mp_face.FACEMESH_TESSELATION,
                mp_draw.DrawingSpec(color=(0, 255, 0), thickness=1, circle_radius=1),
                mp_draw.DrawingSpec(color=(0, 0, 255), thickness=1)
            )

    # === HUD ===
    cv2.putText(frame, f"Label: {label}", (10, 35), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
    cv2.putText(frame, f"Samples: {saved_count}/{MAX_SAMPLES}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)
    cv2.putText(frame, status, (10, 105),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0) if hands_detected else (0,0,255), 2)
    cv2.imshow("ASL Capture (Improved v2)", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("\n🛑 Manual stop triggered.")
        break

cap.release()
cv2.destroyAllWindows()

# === Save CSV ===
columns = []
for hand in ["L1_", "L2_"]:
    for i in range(21):
        columns += [f"{hand}x{i}", f"{hand}y{i}", f"{hand}z{i}"]
for idx in SELECTED_FACE_IDXS:
    columns += [f"Fx{idx}", f"Fy{idx}", f"Fz{idx}"]
columns += ["label", "timestamp"]

df = pd.DataFrame(data, columns=columns)

if not df.empty:
    df.to_csv(SAVE_PATH, index=False)
    print(f"\n💾 Dataset saved: {SAVE_PATH}")
    print(f"📊 Total samples: {len(df)} | Features per sample: {len(columns) - 2}")
else:
    print("🚫 No valid samples collected.")
# Out:
# 📷 Starting data capture for 'shame' in 3 seconds...
#
# ✅ Capture complete.
#
# 💾 Dataset saved: C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\ASLFacialExpressionsLanguages\shame.csv
# 📊 Total samples: 600 | Features per sample: 174

# %%
import os
import pandas as pd

# === Configuration ===
DATASET_DIR = r"C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\ASLFacialExpressionsLanguages\Expressions"
combined_path = os.path.join(DATASET_DIR, "ASL_Facial_Expressions_dataset.csv")

# === Scan for CSV files ===
csv_files = [f for f in os.listdir(DATASET_DIR) if f.endswith(".csv")]
print(f"📁 Found {len(csv_files)} dataset files")

all_dfs = []
all_columns = set()

# === First pass: Collect all columns ===
for csv_file in csv_files:
    path = os.path.join(DATASET_DIR, csv_file)
    try:
        df = pd.read_csv(path)
        if df.empty:
            print(f"⚠️ Skipped empty file: {csv_file}")
            continue
        if "label" not in df.columns:
            print(f"⚠️ 'label' missing in {csv_file}, skipping...")
            continue
        all_columns.update(df.columns)
        print(f"✅ Columns collected from: {csv_file} ({len(df)} samples)")
    except Exception as e:
        print(f"❌ Error reading {csv_file}: {e}")

if not all_columns:
    raise SystemExit("🚫 No valid CSV files found.")

# === Enforce column order identical to capture script ===
SELECTED_FACE_IDXS = [
    33,133,362,263,   # eyes
    1,2,4,5,45,275,   # nose + cheeks
    61,291,0,17,57,287 # mouth + chin
]

columns = []
for hand in ["L1_", "L2_"]:
    for i in range(21):
        columns += [f"{hand}x{i}", f"{hand}y{i}", f"{hand}z{i}"]
for idx in SELECTED_FACE_IDXS:
    columns += [f"Fx{idx}", f"Fy{idx}", f"Fz{idx}"]
columns += ["label", "timestamp"]

# Use this explicit order instead of sorted(all_columns)
all_columns = columns
print(f"✅ Using fixed column order from capture script ({len(all_columns)} columns)")

# === Second pass: Align and merge ===
for csv_file in csv_files:
    path = os.path.join(DATASET_DIR, csv_file)
    try:
        df = pd.read_csv(path)
        if df.empty or "label" not in df.columns:
            continue
        df["label"] = df["label"].astype(str).str.strip().str.lower()
        df = df.reindex(columns=all_columns, fill_value=0)
        all_dfs.append(df)
        print(f"✅ Loaded {csv_file} ({len(df)} samples)")
    except Exception as e:
        print(f"❌ Error loading {csv_file}: {e}")

# === Merge all datasets ===
if all_dfs:
    final_df = pd.concat(all_dfs, ignore_index=True)
    final_df = final_df.sample(frac=1, random_state=42).reset_index(drop=True)
    final_df.to_csv(combined_path, index=False)

    print("\n✅ Combined dataset created successfully!")
    print(f"📄 Saved to: {combined_path}")
    print("🧮 Total samples:", final_df.shape[0])

    if "label" in final_df.columns:
        print("\n📊 Samples per label:")
        print(final_df["label"].value_counts())
        print("\n🏷️ Unique labels:", list(final_df["label"].unique()))
    else:
        print("⚠️ 'label' column missing in merged file!")
else:
    print("🚫 No valid datasets found to merge.")
# Out:
# 📁 Found 6 dataset files
# ✅ Columns collected from: angry.csv (600 samples)
# ❌ Error reading ASL_Facial_Expressions_dataset.csv: No columns to parse from file
# ✅ Columns collected from: happy.csv (600 samples)
# ✅ Columns collected from: sad.csv (600 samples)
# ✅ Columns collected from: shock.csv (600 samples)
# ✅ Columns collected from: smile.csv (600 samples)
# ✅ Using fixed column order from capture script (176 columns)
# ✅ Loaded angry.csv (600 samples)
# ❌ Error loading ASL_Facial_Expressions_dataset.csv: No columns to parse from file
# ✅ Loaded happy.csv (600 samples)
# ✅ Loaded sad.csv (600 samples)
# ✅ Loaded shock.csv (600 samples)
# ✅ Loaded smile.csv (600 samples)
#
# ✅ Combined dataset created successfully!
# 📄 Saved to: C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\ASLFacialExpressionsLanguages\Expressions\ASL_Facial_Expressions_dataset.csv
# 🧮 Total samples: 3000
#
# 📊 Samples per label:
# label
# shock    600
# happy    600
# angry    600
# smile    600
# sad      600
# Name: count, dtype: int64
#
# 🏷️ Unique labels: ['shock', 'happy', 'angry', 'smile', 'sad']

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import joblib

# === Configuration ===
DATA_PATH = r"C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\ASLFacialExpressionsLanguages\Expressions\ASL_Facial_Expressions_dataset.csv"
MODEL_DIR = r"C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages"
MODEL_PATH = os.path.join(MODEL_DIR, "expressions_model_tf.keras")
TFLITE_PATH = os.path.join(MODEL_DIR, "expressions_model_tf.tflite")

os.makedirs(MODEL_DIR, exist_ok=True)

# === Step 1: Load and Inspect Dataset ===
print("📥 Loading dataset...")
df = pd.read_csv(DATA_PATH)
print(f"✅ Dataset loaded: {df.shape[0]} samples, {df.shape[1]} columns")

if "label" not in df.columns:
    raise ValueError("🚫 'label' column not found in dataset!")

# === Step 2: Clean Data ===
X = df.drop(columns=["label", "timestamp"], errors="ignore").fillna(0)
y = df["label"]
X = X.select_dtypes(include=[np.number])
# Replace zeros with NaN and fill with column means to stabilize scaling
X = X.replace(0, np.nan)
X = X.fillna(X.mean())
print(f"🔧 Replaced zeros with feature means → shape: {X.shape}")



print(f"🔢 Feature matrix shape: {X.shape}")
print("🏷️ Labels found:", y.unique())

# === Step 3: Balance Classes ===
print("⚖️ Balancing dataset...")
max_samples = y.value_counts().max()
df_balanced = df.groupby("label", group_keys=False).apply(
    lambda x: resample(x, replace=True, n_samples=max_samples, random_state=42)
)
X = df_balanced.drop(columns=["label", "timestamp"], errors="ignore").fillna(0)
y = df_balanced["label"]
print(df_balanced["label"].value_counts())

# === Step 4: Encode Labels ===
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)
print(f"🔢 Encoded {num_classes} classes →", list(label_encoder.classes_))

# === Step 5: Normalize Features ===
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# === Step 6: Split Data ===
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.2, stratify=y_encoded, random_state=42
)
print("📊 Data split complete (80% train / 20% test)")

# === Step 7: Define Neural Network Model ===
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),  # ✅ compatible version
    metrics=['accuracy']
)


model.summary()

# === Step 8: Train Model with EarlyStopping ===
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ModelCheckpoint(MODEL_PATH, save_best_only=True, monitor='val_accuracy', verbose=1)
]

print("\n🚀 Training model...")
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,          # ⬅️ longer training
    batch_size=16,       # ⬅️ smaller batch for finer updates
    callbacks=callbacks,
    verbose=1
)

# === Step 9: Evaluate Model ===
y_pred = np.argmax(model.predict(X_test), axis=1)
acc = accuracy_score(y_test, y_pred)

print(f"\n🎯 Test Accuracy: {acc * 100:.2f}%")
print("\n📄 Classification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
print("🧾 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# === Step 10: Save Assets ===
joblib.dump(scaler, os.path.join(MODEL_DIR, "expressions_model_tf_scaler.pkl"))
np.save(os.path.join(MODEL_DIR, "expressions_model_tf_labels.npy"), label_encoder.classes_)

print(f"\n💾 Model saved → {MODEL_PATH}")
print(f"📏 Scaler saved → {MODEL_DIR}\\expressions_model_tf_scaler.pkl")
print(f"🏷️ Labels saved → {MODEL_DIR}\\expressions_model_tf_labels.npy")

# === Step 11: Convert to TFLite ===
print("\n⚙️ Converting to TensorFlow Lite (.tflite)...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(TFLITE_PATH, "wb") as f:
    f.write(tflite_model)

print(f"✅ TFLite model saved → {TFLITE_PATH}")
print("\n🏁 Training + Conversion complete!")
# Out:
# 📥 Loading dataset...
# ✅ Dataset loaded: 3000 samples, 176 columns
# 🔧 Removed all-zero columns → New feature count: 174
# 🔢 Feature matrix shape: (3000, 174)
# 🏷️ Labels found: ['shock' 'happy' 'angry' 'smile' 'sad']
# ⚖️ Balancing dataset...
# label
# angry    600
# happy    600
# sad      600
# shock    600
# smile    600
# Name: count, dtype: int64
# 🔢 Encoded 5 classes → ['angry', 'happy', 'sad', 'shock', 'smile']
# 📊 Data split complete (80% train / 20% test)
# C:\Users\JamJayDatuin\AppData\Local\Temp\ipykernel_15040\1601047211.py:44: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_balanced = df.groupby("label", group_keys=False).apply(
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 512)            │        89,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 258,053 (1008.02 KB)
#  Trainable params: 256,261 (1001.02 KB)
#  Non-trainable params: 1,792 (7.00 KB)
# 🚀 Training model...
# Epoch 1/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7349 - loss: 0.7780
# Epoch 1: val_accuracy improved from None to 0.99792, saving model to C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8734 - loss: 0.3760 - val_accuracy: 0.9979 - val_loss: 0.0790
# Epoch 2/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9638 - loss: 0.1223
# Epoch 2: val_accuracy did not improve from 0.99792
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9688 - loss: 0.1056 - val_accuracy: 0.9979 - val_loss: 0.0142
# Epoch 3/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.0631
# Epoch 3: val_accuracy improved from 0.99792 to 1.00000, saving model to C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9833 - loss: 0.0623 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 4/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9904 - loss: 0.0417
# Epoch 4: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9906 - loss: 0.0386 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 5/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0464
# Epoch 5: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9901 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 6/100
# 113/120 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0289
# Epoch 6: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9927 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 5.0047e-04
# Epoch 7/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9933 - loss: 0.0227
# Epoch 7: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9911 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 8/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9915 - loss: 0.0303
# Epoch 8: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9901 - loss: 0.0358 - val_accuracy: 1.0000 - val_loss: 4.1987e-04
# Epoch 9/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0302
# Epoch 9: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9927 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 3.5100e-04
# Epoch 10/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.0149
# Epoch 10: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9948 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 3.4832e-04
# Epoch 11/100
# 113/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9952 - loss: 0.0222
# Epoch 11: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9943 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 6.3602e-04
# Epoch 12/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.0080
# Epoch 12: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 4.5482e-04
# Epoch 13/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9921 - loss: 0.0250
# Epoch 13: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9953 - loss: 0.0171 - val_accuracy: 0.9979 - val_loss: 0.0029
# Epoch 14/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9877 - loss: 0.0281
# Epoch 14: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9896 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 2.6820e-04
# Epoch 15/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9963 - loss: 0.0182
# Epoch 15: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9958 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 2.2427e-04
# Epoch 16/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9984 - loss: 0.0076
# Epoch 16: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 1.0016e-04
# Epoch 17/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0160
# Epoch 17: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9932 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 6.1730e-05
# Epoch 18/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9997 - loss: 0.0040
# Epoch 18: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 4.9028e-05
# Epoch 19/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9995 - loss: 0.0061
# Epoch 19: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 1.0222e-04
# Epoch 20/100
# 113/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0053
# Epoch 20: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 3.7813e-05
# Epoch 21/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9941 - loss: 0.0136
# Epoch 21: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9943 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 1.3947e-04
# Epoch 22/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0132
# Epoch 22: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9948 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 2.0141e-04
# Epoch 23/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9952 - loss: 0.0184
# Epoch 23: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9943 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 8.3927e-05
# Epoch 24/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.0156
# Epoch 24: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9948 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 6.5815e-05
# Epoch 25/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9946 - loss: 0.0179
# Epoch 25: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9943 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 6.7317e-05
# Epoch 26/100
# 113/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9947 - loss: 0.0184
# Epoch 26: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9964 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 1.1752e-04
# Epoch 27/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9917 - loss: 0.0248
# Epoch 27: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9948 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 7.0323e-05
# Epoch 28/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.0112
# Epoch 28: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9974 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 2.3314e-04
# Epoch 29/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0093
# Epoch 29: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 2.1723e-04
# Epoch 30/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0058
# Epoch 30: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9969 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 2.8030e-05
# Epoch 31/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9982 - loss: 0.0082
# Epoch 31: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9958 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 32/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9982 - loss: 0.0105
# Epoch 32: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9969 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 2.9079e-04
# Epoch 33/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9947 - loss: 0.0219
# Epoch 33: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9943 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 3.9007e-04
# Epoch 34/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.0213
# Epoch 34: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 5.2450e-04
# Epoch 35/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9999 - loss: 0.0032
# Epoch 35: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9995 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 5.7521e-05
# Epoch 36/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9968 - loss: 0.0097
# Epoch 36: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9943 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 7.3491e-05
# Epoch 37/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9952 - loss: 0.0186
# Epoch 37: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9969 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 5.8489e-05
# Epoch 38/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9959 - loss: 0.0106
# Epoch 38: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9974 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 4.0099e-05
# Epoch 39/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.0029
# Epoch 39: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 6.3073e-05
# Epoch 40/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9984 - loss: 0.0089
# Epoch 40: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9964 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 1.7800e-04
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# 🎯 Test Accuracy: 100.00%
#
# 📄 Classification Report:
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00       120
#        happy       1.00      1.00      1.00       120
#          sad       1.00      1.00      1.00       120
#        shock       1.00      1.00      1.00       120
#        smile       1.00      1.00      1.00       120
#
#     accuracy                           1.00       600
#    macro avg       1.00      1.00      1.00       600
# weighted avg       1.00      1.00      1.00       600
#
# 🧾 Confusion Matrix:
# [[120   0   0   0   0]
#  [  0 120   0   0   0]
#  [  0   0 120   0   0]
#  [  0   0   0 120   0]
#  [  0   0   0   0 120]]
#
# 💾 Model saved → C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf.keras
# 📏 Scaler saved → C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf_scaler.pkl
# 🏷️ Labels saved → C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf_labels.npy
#
# ⚙️ Converting to TensorFlow Lite (.tflite)...
# INFO:tensorflow:Assets written to: C:\Users\JAMJAY~1\AppData\Local\Temp\tmp3yjyjxig\assets
# INFO:tensorflow:Assets written to: C:\Users\JAMJAY~1\AppData\Local\Temp\tmp3yjyjxig\assets
# Saved artifact at 'C:\Users\JAMJAY~1\AppData\Local\Temp\tmp3yjyjxig'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 174), dtype=tf.float32, name='keras_tensor_66')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   1330970370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970365008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1328638523152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1328638523344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1328638522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745098704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745099856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970369040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330970370384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1329745099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330403303952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1330403309904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved → C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages\expressions_model_tf.tflite
#
# 🏁 Training + Conversion complete!

# %%
import cv2
import mediapipe as mp
import numpy as np
import joblib
import pandas as pd
import tensorflow as tf
from collections import deque, Counter

# === Configuration ===
MODEL_DIR = r"C:\Users\JamJayDatuin\Documents\Machine Learning Projects\TrainingAI-Models\Models\ASLFacialExpressionsLanguages"
TFLITE_MODEL_PATH = f"{MODEL_DIR}\\expressions_model_tf.tflite"
SCALER_PATH       = f"{MODEL_DIR}\\expressions_model_tf_scaler.pkl"
LABELS_PATH       = f"{MODEL_DIR}\\expressions_model_tf_labels.npy"

# === Load Model and Preprocessors ===
print("📦 Loading TFLite model and preprocessing assets...")
interpreter = tf.lite.Interpreter(model_path=TFLITE_MODEL_PATH)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

scaler = joblib.load(SCALER_PATH)
labels = np.load(LABELS_PATH, allow_pickle=True)
print(f"✅ Model loaded — expects {input_details[0]['shape'][1]} features")
print(f"🏷️ Classes: {list(labels)}")

# === MediaPipe Setup ===
mp_hands = mp.solutions.hands
mp_face = mp.solutions.face_mesh
mp_draw = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.8,
    min_tracking_confidence=0.8
)
face_mesh = mp_face.FaceMesh(
    static_image_mode=False,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.8
)

# === Selected Face Landmarks (same as training) ===
SELECTED_FACE_IDXS = [
    33,133,362,263,   # eyes
    1,2,4,5,45,275,   # nose + cheeks
    61,291,0,17,57,287 # mouth + chin
]

# === Prediction Stability Settings ===
WINDOW_SIZE = 10
CONF_THRESHOLD = 0.60         # baseline prediction confidence
UNKNOWN_THRESHOLD = 0.35      # for "Can't be Found"
prediction_window = deque(maxlen=WINDOW_SIZE)

def majority_vote(predictions):
    """Returns most common prediction within the window."""
    if not predictions:
        return None
    counter = Counter(predictions)
    return counter.most_common(1)[0][0]

# === Start Camera ===
cap = cv2.VideoCapture(0)
print("📸 Camera started — press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.flip(frame, 1)
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # === Detect hands and face ===
    hand_results = hands.process(rgb)
    face_results = face_mesh.process(rgb)

    row = []
    hands_detected = False
    face_detected = False

    # --- HAND LANDMARKS (2 hands) ---
    if hand_results.multi_hand_landmarks:
        hands_detected = True
        for hand_landmarks in hand_results.multi_hand_landmarks[:2]:
            for lm in hand_landmarks.landmark:
                row.extend([lm.x, lm.y, lm.z])
        if len(hand_results.multi_hand_landmarks) == 1:
            row.extend([0] * (21 * 3))
    else:
        row.extend([0] * (21 * 3 * 2))

    # --- FACE LANDMARKS ---
    if face_results.multi_face_landmarks:
        face_detected = True
        for idx in SELECTED_FACE_IDXS:
            lm = face_results.multi_face_landmarks[0].landmark[idx]
            row.extend([lm.x, lm.y, lm.z])
    else:
        row.extend([0] * (len(SELECTED_FACE_IDXS) * 3))

    # === PREDICTION LOGIC ===
    if not (hands_detected or face_detected):
        text = "No Hands or Face to Detect"
        color = (0, 0, 255)  # red
    elif len(row) == input_details[0]['shape'][1]:
        X_live = pd.DataFrame([row])
        X_scaled = scaler.transform(X_live).astype(np.float32)

        # Run inference
        interpreter.set_tensor(input_details[0]['index'], X_scaled)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])[0]

        pred_conf = np.max(output)
        pred_label = labels[np.argmax(output)]

        # --- Unknown Gesture / Low Confidence ---
        if pred_conf < UNKNOWN_THRESHOLD:
            text = "Can't be Found"
            color = (0, 165, 255)  # orange
            prediction_window.clear()  # reset stability buffer
        elif pred_conf >= CONF_THRESHOLD:
            prediction_window.append(pred_label)
            stable_pred = majority_vote(prediction_window)
            text = f"{stable_pred.upper()} ({pred_conf:.2f})"
            color = (0, 255, 0)  # green
        else:
            text = f"Low Confidence ({pred_conf:.2f})"
            color = (0, 255, 255)  # yellow
    else:
        text = "⚠️ Invalid landmark vector"
        color = (0, 0, 255)

    # === Draw Landmarks ===
    if hand_results.multi_hand_landmarks:
        for hl in hand_results.multi_hand_landmarks:
            mp_draw.draw_landmarks(frame, hl, mp_hands.HAND_CONNECTIONS)
    if face_results.multi_face_landmarks:
        for fl in face_results.multi_face_landmarks:
            mp_draw.draw_landmarks(
                frame, fl, mp_face.FACEMESH_TESSELATION,
                mp_draw.DrawingSpec(color=(0, 255, 0), thickness=1, circle_radius=1),
                mp_draw.DrawingSpec(color=(0, 0, 255), thickness=1)
            )

    # === Overlay prediction ===
    cv2.putText(frame, text, (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)
    cv2.putText(frame, f"Frames stabilized: {len(prediction_window)}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

    cv2.imshow("ASL Facial + Hand Expression (TFLite)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
print("👋 Session ended.")
# Out:
# 📦 Loading TFLite model and preprocessing assets...
# ✅ Model loaded — expects 174 features
# 🏷️ Classes: ['angry', 'happy', 'sad', 'shock', 'smile']
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# 📸 Camera started — press 'q' to quit.
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\JamJayDatuin\Documents\Machine Learning Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 👋 Session ended.
